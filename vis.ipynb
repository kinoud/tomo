# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_img(i):
    img = np.fromfile('模拟投影数据/平行移动轨迹/单幅/projectImage%d.raw'%i,dtype='uint32')
#     print(img.shape, np.min(img), np.max(img))
    img = img/255
    img = img.reshape((3000,3000))
    return img

plt.figure(figsize=(20,20)) #单位厘米？
plt.axis('off')
for i in range(1,31):
    plt.subplot(6,5,i)
    plt.imshow(get_img(i), cmap='gray')
plt.show()

# %%
def get_img1(i):
    img = np.fromfile('exp/proj/shepp_logan/projectImage%d.raw'%i,dtype='uint16')
#     print(img.shape, np.min(img), np.max(img))
    img = img/255
    img = img.reshape((3000,3000))
    return img

def get_img2(i):
    img = np.fromfile('proj/shepp_logan_400x400x100_uint8.rec_la05_it1.raw.translation.in.proj/projectImage%d.raw'%i,dtype='uint8')
#     print(img.shape, np.min(img), np.max(img))
    img = img/255
    img = img.reshape((3000,3000))
    return img

plt.figure(figsize=(20,50)) #单位厘米？
plt.axis('off')
plt.imshow(get_img1(1),cmap='gray')
# for i in range(1,5):
#     plt.subplot(5,2,2*i-1)
#     plt.imshow(get_img1(i), cmap='gray')
#     plt.subplot(5,2,2*i)
#     plt.imshow(get_img2(i), cmap='gray')
# plt.show()

# %%
def get_img(i):
    img = np.fromfile('proj/shepp_logan_400x400x100_uint8.rec_la05_it1.raw.translation.in.proj/projectImage%d.raw'%i,dtype='uint8')
#     print(img.shape, np.min(img), np.max(img))
    img = img/255
    img = img.reshape((3000,3000))
    return img

plt.figure(figsize=(20,20)) #单位厘米？
plt.axis('off')
for i in range(1,31):
    plt.subplot(6,5,i)
    plt.imshow(get_img(i), cmap='gray')
plt.show()
