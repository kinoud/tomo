# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_img(i):
    img = np.fromfile('exp/proj/shepp_logan/projectImage%d.raw'%i,dtype='uint16')
    img = img.reshape((3000,3000))
    return img

plt.figure(figsize=(20,40))
plt.axis('off')
for i in range(1,31):
    plt.subplot(8,4,i)
    plt.imshow(get_img(i), cmap='gray')
plt.show()

# %%
a = np.fromfile('exp/vox/head_400x400x328.raw',dtype='uint16').reshape(400,400,328)
plt.imshow(a[:,:,327],cmap='gray')
plt.show()

# %%
a = np.fromfile('exp/proj/siddon/head_circle/projectImage1.raw',dtype='uint16').reshape(3000,3000)

# %%
b = a[1000:2000,500:1600]
plt.figure(figsize=(10,10))
plt.imshow(b,cmap='gray')
plt.show()

# %%
c = np.exp(-(b.astype('float'))/65535)
plt.figure(figsize=(10,10))
plt.imshow(c,cmap='gray_r')
plt.show()
